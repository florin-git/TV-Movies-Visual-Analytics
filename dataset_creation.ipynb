# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Pre-processing

# %%
# TV Guide dataset
dataset_path = "./dataset/movie_without_december.tsv"

# %%
df = pd.read_csv(dataset_path, sep="\t")

# %%
df
# Out:
#             day  day_number    month     daytime   hour  \
# 0       Martedì          25  gennaio       notte  01:01
# 1       Martedì          25  gennaio       notte  01:10
# 2       Martedì          25  gennaio       notte  01:10
# 3       Martedì          25  gennaio       notte  01:15
# 4       Martedì          25  gennaio       notte  01:22
# ...         ...         ...      ...         ...    ...
# 69621  Domenica          24   aprile  pomeriggio  16:15
# 69622  Domenica          24   aprile  pomeriggio  16:15
# 69623  Domenica          24   aprile  pomeriggio  16:35
# 69624  Domenica          24   aprile  pomeriggio  16:55
# 69625  Domenica          24   aprile  pomeriggio  16:55
#
#                                title duration                  channel
# 0               Piccolo grande aaron     105'                     Iris
# 1                        Match Point     125'           Sky Cinema Due
# 2                     The Blind Side     130'       Sky Cinema Due +24
# 3               From Paris with love      95'        Sky Cinema Action
# 4                   Volesse il cielo      87'                   Cine34
# ...                              ...      ...                      ...
# 69621                 Transformers 4     165'  Harry Potter Collection
# 69622                    Cloud Atlas     175'         Sky Cinema Drama
# 69623                     Il Padrino     175'            Sky Cinema 4K
# 69624                      Tre piani     125'           Sky Cinema Due
# 69625  Delicieux: l'amore e' servito     120'       Sky Cinema Due +24
#
# [69626 rows x 8 columns]

# %%
# Make titles in lower case
df['title'] = df['title'].str.lower()

# %%
tv_movies = df['title'].unique()

# %%
tv_movies.shape
# Out:
# (7749,)

# %%
kaggle_path = "./dataset/Kaggle/ImdbTitleBasics.csv"

# %%
df_imdb = pd.read_csv(kaggle_path, sep=",")
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_imdb
# Out:
#              tconst  titleType                         primaryTitle  \
# 0         tt0000001      short                           Carmencita
# 1         tt0000002      short               Le clown et ses chiens
# 2         tt0000003      short                       Pauvre Pierrot
# 3         tt0000004      short                          Un bon bock
# 4         tt0000005      short                     Blacksmith Scene
# ...             ...        ...                                  ...
# 1048570  tt10140376   tvSeries                      Começar do Zero
# 1048571  tt10140378  tvEpisode                           Corey Hart
# 1048572   tt1014037  tvEpisode                               Escape
# 1048573  tt10140380      short                         Fear of Dogs
# 1048574  tt10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 0                                 Carmencita        0      1894      \N
# 1                     Le clown et ses chiens        0      1892      \N
# 2                             Pauvre Pierrot        0      1892      \N
# 3                                Un bon bock        0      1892      \N
# 4                           Blacksmith Scene        0      1893      \N
# ...                                      ...      ...       ...     ...
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 1048570             90                Reality-TV
# 1048571             \N                 Talk-Show
# 1048572             29               Documentary
# 1048573             \N               Drama,Short
# 1048574             \N                     Music
#
# [1048575 rows x 9 columns]

# %%
# Change column name for the subsequent merge with the TV Guide dataset
df_imdb.rename(columns = {'originalTitle':'title'}, inplace = True)
df_imdb['title'] = df_imdb['title'].str.lower()
df_imdb['primaryTitle'] = df_imdb['primaryTitle'].str.lower()

# %%
only_movies = df_imdb[df_imdb['titleType'] == "movie"]

# %%
# Remove movies with same titles
only_movies_without_duplicates = only_movies.drop_duplicates(subset=['title'], keep=False)

# %%
only_movies_without_duplicates
# Out:
#              tconst titleType                    primaryTitle  \
# 570       tt0000574     movie     the story of the kelly gang
# 672       tt0000679     movie  the fairylogue and radio-plays
# 729       tt0000739     movie       el pastorcito de torrente
# 804       tt0000814     movie          la bocana de mar chica
# 828       tt0000838     movie              a cultura do cacau
# ...             ...       ...                             ...
# 1048453  tt10140138     movie                         krocken
# 1048479  tt10140192     movie           le calvaire de mignon
# 1048497  tt10140224     movie                     inner child
# 1048537  tt10140310     movie            a rock n' roll heart
# 1048566  tt10140360     movie          another night in china
#
#                                   title  isAdult startYear endYear  \
# 570         the story of the kelly gang        0      1906      \N
# 672      the fairylogue and radio-plays        0      1908      \N
# 729           el pastorcito de torrente        0      1908      \N
# 804              la bocana de mar chica        0      1909      \N
# 828                  a cultura do cacau        0      1909      \N
# ...                                 ...      ...       ...     ...
# 1048453                         krocken        0      2018      \N
# 1048479           le calvaire de mignon        0      1917      \N
# 1048497                     inner child        0        \N      \N
# 1048537            a rock n' roll heart        0      2019      \N
# 1048566          another night in china        1      2009      \N
#
#         runtimeMinutes                      genres
# 570                 70  Action,Adventure,Biography
# 672                120           Adventure,Fantasy
# 729                 \N                       Drama
# 804                 \N                          \N
# 828                 \N                          \N
# ...                ...                         ...
# 1048453             82                Comedy,Drama
# 1048479             55                     Romance
# 1048497             \N            Fantasy,Thriller
# 1048537             77              Comedy,Romance
# 1048566             \N                       Adult
#
# [200720 rows x 9 columns]

# %%
df_merge = pd.merge(df, only_movies_without_duplicates, how="inner", on="title")

# %%
titles_merge = df_merge['title'].unique()

# %%
titles_merge.shape
# Out:
# (1751,)

# %%
df_merge['channel'].unique()
# Out:
# array(['Sky Cinema Due', 'Sky Cinema Due +24', 'Iris',
#        'Harry Potter Collection', 'Sky Cinema Drama', 'Cine34',
#        'Sky Cinema Suspense', 'Sky Cinema Romance', 'Sky Cinema Uno +24',
#        'Sky Cinema Family', 'La5', 'Sky Cinema Uno', 'Rete 4',
#        'Sky Cinema Action', '27 Twentyseven', 'Canale 20', 'Cielo',
#        'Sky Cinema 4K', 'Sky Cinema Comedy', 'Explorer Channel', 'TV8',
#        'Canale 5', 'La7D', 'La7', 'Sky Nature', 'NOVE', 'Italia 1',
#        'TV2000', 'Italia 2', 'Sky Arte', 'San Marino RTV',
#        'Comedy Central', 'Boomerang', 'Cartoonito', 'K2', 'Boing',
#        'Focus TV', 'DeAKids', 'Sky Documentaries', 'Top Crime'],
#       dtype=object)

# %%
df_num_movies = df_merge.groupby(['channel'])['channel'].count()

# %%
considered_channels = ["Cielo", "Italia 1", "Iris", "Rete 4", "Cine34", "Sky Cinema Drama", "Sky Cinema Due", "Sky Cinema Suspense", "Sky Cinema Comedy", "Sky Cinema Action"]

# %%
# Keep only tuples of the considered channels
df_final_without_ratings = df_merge.loc[df_merge['channel'].isin(considered_channels)]

# %%
df_final_without_ratings
# Out:
#              day  day_number      month  daytime   hour  \
# 0        Martedì          25    gennaio    notte  01:10
# 1        Martedì          26     aprile    notte  04:35
# 3      Mercoledì          10     agosto     sera  23:10
# 6         Lunedì           9     maggio    notte  02:25
# 7        Venerdì          19     agosto    notte  01:05
# ...          ...         ...        ...      ...    ...
# 13357     Lunedì           9     maggio  mattina  08:11
# 13358    Giovedì          24      marzo    notte  05:15
# 13359    Venerdì           2  settembre    notte  02:30
# 13360    Martedì          12     aprile    notte  01:28
# 13361    Venerdì          22     luglio    notte  02:25
#
#                               title duration         channel     tconst  \
# 0                       match point     125'  Sky Cinema Due  tt0416320
# 1                       match point     125'  Sky Cinema Due  tt0416320
# 3                       match point     141'            Iris  tt0416320
# 6                       match point     125'  Sky Cinema Due  tt0416320
# 7                       match point     125'  Sky Cinema Due  tt0416320
# ...                             ...      ...             ...        ...
# 13357                 le soldatesse     139'            Iris  tt0059732
# 13358          il figlio di bakunin      86'            Iris  tt0126300
# 13359              6000 km di paura      92'          Rete 4  tt0078194
# 13360           la guerra dei robot      94'          Cine34  tt0077640
# 13361  la polizia ha le mani legate      97'          Rete 4  tt0072008
#
#       titleType        primaryTitle  isAdult startYear endYear runtimeMinutes  \
# 0         movie         match point        0      2005      \N            124
# 1         movie         match point        0      2005      \N            124
# 3         movie         match point        0      2005      \N            124
# 6         movie         match point        0      2005      \N            124
# 7         movie         match point        0      2005      \N            124
# ...         ...                 ...      ...       ...     ...            ...
# 13357     movie  the camp followers        0      1965      \N            119
# 13358     movie  the son of bakunin        0      1997      \N             89
# 13359     movie        safari rally        0      1978      \N             90
# 13360     movie   war of the robots        0      1978      \N            103
# 13361     movie          killer cop        0      1975      \N             95
#
#                        genres
# 0      Drama,Romance,Thriller
# 1      Drama,Romance,Thriller
# 3      Drama,Romance,Thriller
# 6      Drama,Romance,Thriller
# 7      Drama,Romance,Thriller
# ...                       ...
# 13357               Drama,War
# 13358                   Drama
# 13359        Action,Adventure
# 13360        Adventure,Sci-Fi
# 13361      Action,Crime,Drama
#
# [7800 rows x 16 columns]

# %% [markdown]
# ## Import Ratings

# %%
# Import ratings
ratings_path = "./dataset/Kaggle/ImdbTitleRatings.csv"

# %%
df_ratings = pd.read_csv(ratings_path, sep=",")

# %%
df_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1694
# 1        tt0000002            6.0       210
# 2        tt0000003            6.5      1441
# 3        tt0000004            6.1       122
# 4        tt0000005            6.1      2240
# ...            ...            ...       ...
# 1048570  tt7512616            9.0         5
# 1048571  tt7512624            5.5       931
# 1048572  tt7512632            3.4        33
# 1048573  tt7512636            6.4        22
# 1048574  tt7512670            7.0        49
#
# [1048575 rows x 3 columns]

# %%
df_with_ratings = pd.merge(df_final_without_ratings, df_ratings, how="inner", on="tconst")

# %%
df_with_ratings
# Out:
#             day  day_number      month  daytime   hour  \
# 0       Martedì          25    gennaio    notte  01:10
# 1       Martedì          26     aprile    notte  04:35
# 2     Mercoledì          10     agosto     sera  23:10
# 3        Lunedì           9     maggio    notte  02:25
# 4       Venerdì          19     agosto    notte  01:05
# ...         ...         ...        ...      ...    ...
# 7425     Lunedì           9     maggio  mattina  08:11
# 7426    Giovedì          24      marzo    notte  05:15
# 7427    Venerdì           2  settembre    notte  02:30
# 7428    Martedì          12     aprile    notte  01:28
# 7429    Venerdì          22     luglio    notte  02:25
#
#                              title duration         channel     tconst  \
# 0                      match point     125'  Sky Cinema Due  tt0416320
# 1                      match point     125'  Sky Cinema Due  tt0416320
# 2                      match point     141'            Iris  tt0416320
# 3                      match point     125'  Sky Cinema Due  tt0416320
# 4                      match point     125'  Sky Cinema Due  tt0416320
# ...                            ...      ...             ...        ...
# 7425                 le soldatesse     139'            Iris  tt0059732
# 7426          il figlio di bakunin      86'            Iris  tt0126300
# 7427              6000 km di paura      92'          Rete 4  tt0078194
# 7428           la guerra dei robot      94'          Cine34  tt0077640
# 7429  la polizia ha le mani legate      97'          Rete 4  tt0072008
#
#      titleType        primaryTitle  isAdult startYear endYear runtimeMinutes  \
# 0        movie         match point        0      2005      \N            124
# 1        movie         match point        0      2005      \N            124
# 2        movie         match point        0      2005      \N            124
# 3        movie         match point        0      2005      \N            124
# 4        movie         match point        0      2005      \N            124
# ...        ...                 ...      ...       ...     ...            ...
# 7425     movie  the camp followers        0      1965      \N            119
# 7426     movie  the son of bakunin        0      1997      \N             89
# 7427     movie        safari rally        0      1978      \N             90
# 7428     movie   war of the robots        0      1978      \N            103
# 7429     movie          killer cop        0      1975      \N             95
#
#                       genres  averageRating  numVotes
# 0     Drama,Romance,Thriller            7.6    207540
# 1     Drama,Romance,Thriller            7.6    207540
# 2     Drama,Romance,Thriller            7.6    207540
# 3     Drama,Romance,Thriller            7.6    207540
# 4     Drama,Romance,Thriller            7.6    207540
# ...                      ...            ...       ...
# 7425               Drama,War            7.5       434
# 7426                   Drama            7.1        37
# 7427        Action,Adventure            4.8        34
# 7428        Adventure,Sci-Fi            2.7       713
# 7429      Action,Crime,Drama            6.7       326
#
# [7430 rows x 18 columns]

# %%
# Select only the relevant columns
df_final = df_with_ratings[['day', 'day_number', 'month', 'daytime', 'hour', 'title', 'runtimeMinutes', 'duration', 'channel', 'startYear', 'genres', 'averageRating']]

# %%
df_final
# Out:
#             day  day_number      month  daytime   hour  \
# 0       Martedì          25    gennaio    notte  01:10
# 1       Martedì          26     aprile    notte  04:35
# 2     Mercoledì          10     agosto     sera  23:10
# 3        Lunedì           9     maggio    notte  02:25
# 4       Venerdì          19     agosto    notte  01:05
# ...         ...         ...        ...      ...    ...
# 7425     Lunedì           9     maggio  mattina  08:11
# 7426    Giovedì          24      marzo    notte  05:15
# 7427    Venerdì           2  settembre    notte  02:30
# 7428    Martedì          12     aprile    notte  01:28
# 7429    Venerdì          22     luglio    notte  02:25
#
#                              title runtimeMinutes duration         channel  \
# 0                      match point            124     125'  Sky Cinema Due
# 1                      match point            124     125'  Sky Cinema Due
# 2                      match point            124     141'            Iris
# 3                      match point            124     125'  Sky Cinema Due
# 4                      match point            124     125'  Sky Cinema Due
# ...                            ...            ...      ...             ...
# 7425                 le soldatesse            119     139'            Iris
# 7426          il figlio di bakunin             89      86'            Iris
# 7427              6000 km di paura             90      92'          Rete 4
# 7428           la guerra dei robot            103      94'          Cine34
# 7429  la polizia ha le mani legate             95      97'          Rete 4
#
#      startYear                  genres  averageRating
# 0         2005  Drama,Romance,Thriller            7.6
# 1         2005  Drama,Romance,Thriller            7.6
# 2         2005  Drama,Romance,Thriller            7.6
# 3         2005  Drama,Romance,Thriller            7.6
# 4         2005  Drama,Romance,Thriller            7.6
# ...        ...                     ...            ...
# 7425      1965               Drama,War            7.5
# 7426      1997                   Drama            7.1
# 7427      1978        Action,Adventure            4.8
# 7428      1978        Adventure,Sci-Fi            2.7
# 7429      1975      Action,Crime,Drama            6.7
#
# [7430 rows x 12 columns]

# %%
df_final.rename(columns={'runtimeMinutes':'duration', 
                         'duration': 'duration_with_advertising', 
                         'startYear': 'year',
                         'averageRating': 'rating'
                        }, inplace = True)
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_final.isnull().values.any() # There are no missing values in the dataset
# Out:
# False

# %%
# I checked if some of the strings in 'duration_with_advertising' didn't have the quote at the end
any(df_final['duration_with_advertising'].apply(lambda d: print("It doesn't have the quote") if (d[-1] != "'") else False))
# Out:
# False

# %%
# Since there are not strings without the final quote, I can remove it and convert the field in integer
df_final['duration_with_advertising'] = df_final['duration_with_advertising'].apply(lambda d: int(d[:-1]))
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_final['duration_with_advertising']
# Out:
# 0       125
# 1       125
# 2       141
# 3       125
# 4       125
#        ...
# 7425    139
# 7426     86
# 7427     92
# 7428     94
# 7429     97
# Name: duration_with_advertising, Length: 7430, dtype: int64

# %%
# Actually in the Kaggle Dataset the missing values are specified with the keyword '\\N'
df_with_nan = df_final[(df_final['duration'] == "\\N") | (df_final['year'] == "\\N") | (df_final['genres'] == "\\N") | (df_final['rating'] == "\\N")]

# %%
df_with_nan.sort_values(by='title')[29:]
# Out:
#             day  day_number      month     daytime   hour  \
# 5467  Mercoledì          20     luglio       notte  04:08
# 5468    Giovedì          21     luglio       notte  02:29
# 7208     Sabato          12      marzo        sera  23:46
# 7209     Sabato           4     giugno       notte  04:51
# 7117    Venerdì          16  settembre        sera  21:14
# ...         ...         ...        ...         ...    ...
# 3029    Venerdì           4      marzo     mattina  09:35
# 3023   Domenica          26     giugno  pomeriggio  13:10
# 2438     Lunedì          10    gennaio       notte  02:12
# 3664     Sabato          15    ottobre       notte  04:57
# 3665    Giovedì           8  settembre     mattina  07:22
#
#                          title duration  duration_with_advertising  \
# 5467        assicurasi vergine      100                         96
# 5468        assicurasi vergine      100                         96
# 7208  atti impuri all'italiana       \N                        102
# 7209  atti impuri all'italiana       \N                         69
# 7117                   balloon       \N                        150
# ...                        ...      ...                        ...
# 3029            the kelly gang       \N                        130
# 3023            the kelly gang       \N                        125
# 2438          una macchia rosa       \N                        100
# 3664           vai alla grande       \N                         87
# 3665           vai alla grande       \N                        101
#
#                channel  year          genres  rating
# 5467            Cine34  1967              \N     4.8
# 5468            Cine34  1967              \N     4.8
# 7208            Cine34  1976          Comedy     3.6
# 7209            Rete 4  1976          Comedy     3.6
# 7117              Iris  1982              \N     4.0
# ...                ...   ...             ...     ...
# 3029  Sky Cinema Drama  1920     Crime,Drama     6.3
# 3023  Sky Cinema Drama  1920     Crime,Drama     6.3
# 2438            Rete 4  1970           Drama     7.4
# 3664          Italia 1  1983  Comedy,Romance     3.8
# 3665              Iris  1983  Comedy,Romance     3.8
#
# [194 rows x 12 columns]

# %%
# I started to manually get the duration of the movies
"acts of violence" : 82
"al cuore si comanda": 107
"atti impuri all'italiana": 95
"burro": 90

# %%
df_final['duration'].loc[df_final['title'].isin(["burro"])] = 90
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Remove tuples with missing values
df_final.drop(df_with_nan.index, inplace=True)
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_final['duration'] = df_final['duration'].astype('int64')
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_final
# Out:
#             day  day_number      month  daytime   hour  \
# 0       Martedì          25    gennaio    notte  01:10
# 1       Martedì          26     aprile    notte  04:35
# 2     Mercoledì          10     agosto     sera  23:10
# 3        Lunedì           9     maggio    notte  02:25
# 4       Venerdì          19     agosto    notte  01:05
# ...         ...         ...        ...      ...    ...
# 7425     Lunedì           9     maggio  mattina  08:11
# 7426    Giovedì          24      marzo    notte  05:15
# 7427    Venerdì           2  settembre    notte  02:30
# 7428    Martedì          12     aprile    notte  01:28
# 7429    Venerdì          22     luglio    notte  02:25
#
#                              title  duration  duration_with_advertising  \
# 0                      match point       124                        125
# 1                      match point       124                        125
# 2                      match point       124                        141
# 3                      match point       124                        125
# 4                      match point       124                        125
# ...                            ...       ...                        ...
# 7425                 le soldatesse       119                        139
# 7426          il figlio di bakunin        89                         86
# 7427              6000 km di paura        90                         92
# 7428           la guerra dei robot       103                         94
# 7429  la polizia ha le mani legate        95                         97
#
#              channel  year                  genres  rating
# 0     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6
# 1     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6
# 2               Iris  2005  Drama,Romance,Thriller     7.6
# 3     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6
# 4     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6
# ...              ...   ...                     ...     ...
# 7425            Iris  1965               Drama,War     7.5
# 7426            Iris  1997                   Drama     7.1
# 7427          Rete 4  1978        Action,Adventure     4.8
# 7428          Cine34  1978        Adventure,Sci-Fi     2.7
# 7429          Rete 4  1975      Action,Crime,Drama     6.7
#
# [7207 rows x 12 columns]

# %%
# Explicitly get the advertising duration
df_final['advertising'] = df_final['duration_with_advertising'] - df_final['duration']
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Movies for which the advertising time is negative, contain some wrong information, so they are removed. 
df_final = df_final[df_final['advertising'] >= 0]

# %% [markdown]
# Similarity between movies given by:
# daytime, genres, advertising,

# %%
final_path = "./dataset/df_final.csv"

# %%
# df_final.to_csv(final_path, index=False)

# %%
df_final = pd.read_csv(final_path)

# %%
df_final
# Out:
#             day  day_number      month  daytime   hour  \
# 0       Martedì          25    gennaio    notte  01:10
# 1       Martedì          26     aprile    notte  04:35
# 2     Mercoledì          10     agosto     sera  23:10
# 3        Lunedì           9     maggio    notte  02:25
# 4       Venerdì          19     agosto    notte  01:05
# ...         ...         ...        ...      ...    ...
# 7420    Giovedì          10   novembre    notte  00:52
# 7422  Mercoledì           2   febbraio  mattina  08:47
# 7425     Lunedì           9     maggio  mattina  08:11
# 7427    Venerdì           2  settembre    notte  02:30
# 7429    Venerdì          22     luglio    notte  02:25
#
#                              title  duration  duration_with_advertising  \
# 0                      match point       124                        125
# 1                      match point       124                        125
# 2                      match point       124                        141
# 3                      match point       124                        125
# 4                      match point       124                        125
# ...                            ...       ...                        ...
# 7420                   meo patacca       124                        138
# 7422                  i prepotenti        93                        101
# 7425                 le soldatesse       119                        139
# 7427              6000 km di paura        90                         92
# 7429  la polizia ha le mani legate        95                         97
#
#              channel  year                  genres  rating  advertising
# 0     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6            1
# 1     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6            1
# 2               Iris  2005  Drama,Romance,Thriller     7.6           17
# 3     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6            1
# 4     Sky Cinema Due  2005  Drama,Romance,Thriller     7.6            1
# ...              ...   ...                     ...     ...          ...
# 7420          Rete 4  1972        Adventure,Comedy     6.2           14
# 7422            Iris  1958                  Comedy     6.5            8
# 7425            Iris  1965               Drama,War     7.5           20
# 7427          Rete 4  1978        Action,Adventure     4.8            2
# 7429          Rete 4  1975      Action,Crime,Drama     6.7            2
#
# [5725 rows x 13 columns]

# %% [markdown]
# ## Add other info

# %%
mean_duration = df_final.groupby(["channel","month"])["duration"].mean()
mean_duration_with_adv = df_final.groupby(["channel","month"])["duration_with_advertising"].mean()

# %%
df_final['title'].unique().shape
# Out:
# (1174,)

# %%
# Join durations together
durations = pd.merge(mean_duration, mean_duration_with_adv, on=["month","channel"])

# %%
durations
# Out:
#                                  duration  duration_with_advertising
# month     channel
# agosto    Cielo                 98.142857                 106.428571
# aprile    Cielo                 94.176471                 108.823529
# febbraio  Cielo                 93.333333                 106.111111
# gennaio   Cielo                 88.437500                 102.812500
# giugno    Cielo                 90.050000                 103.000000
# ...                                   ...                        ...
# maggio    Sky Cinema Suspense  102.145161                 114.274194
# marzo     Sky Cinema Suspense  104.600000                 113.083333
# novembre  Sky Cinema Suspense  112.372093                 127.790698
# ottobre   Sky Cinema Suspense  105.978723                 123.404255
# settembre Sky Cinema Suspense  106.000000                 120.636364
#
# [110 rows x 2 columns]

# %%
df_final_with_mean_durations = pd.merge(df_final, durations, on=["month","channel"])

# %%
df_final_with_mean_durations.rename(columns = {'duration_with_advertising_x':'duration_with_advertising', 'duration_x':'duration','duration_y' : 'duration_mean', 'duration_with_advertising_y' : 'duration_with_advertising_mean'}, inplace = True)

# %%
df_final_with_mean_durations
# Out:
#             day  day_number    month     daytime   hour  \
# 0       Martedì          25  gennaio       notte  01:10
# 1        Lunedì          24  gennaio       notte  01:10
# 2       Giovedì          20  gennaio  pomeriggio  13:35
# 3        Sabato          29  gennaio       notte  04:10
# 4     Mercoledì           5  gennaio        sera  23:05
# ...         ...         ...      ...         ...    ...
# 5720    Venerdì          20   maggio        sera  21:20
# 5721    Martedì          24   maggio        sera  23:00
# 5722     Sabato          21   maggio        sera  21:20
# 5723  Mercoledì          25   maggio        sera  23:05
# 5724     Sabato          28   maggio        sera  21:20
#
#                                      title  duration  \
# 0                              match point       124
# 1                           the blind side       129
# 2     la leggenda del pianista sull'oceano       169
# 3                               il profeta       100
# 4                          michael clayton       119
# ...                                    ...       ...
# 5720                    spogliando valeria        92
# 5721                    spogliando valeria        92
# 5722                             la nipote        92
# 5723                             la nipote        92
# 5724                          l'attenzione        87
#
#       duration_with_advertising         channel  year                  genres  \
# 0                           125  Sky Cinema Due  2005  Drama,Romance,Thriller
# 1                           130  Sky Cinema Due  2009   Biography,Drama,Sport
# 2                           170  Sky Cinema Due  1998     Drama,Music,Romance
# 3                           155  Sky Cinema Due  1968                  Comedy
# 4                           125  Sky Cinema Due  2007     Crime,Drama,Mystery
# ...                         ...             ...   ...                     ...
# 5720                        110           Cielo  1989        Romance,Thriller
# 5721                        110           Cielo  1989        Romance,Thriller
# 5722                        105           Cielo  1974                  Comedy
# 5723                        110           Cielo  1974                  Comedy
# 5724                        110           Cielo  1985           Drama,Romance
#
#       rating  advertising  duration_mean  duration_with_advertising_mean
# 0        7.6            1     117.508197                      125.819672
# 1        7.6            1     117.508197                      125.819672
# 2        8.1            1     117.508197                      125.819672
# 3        6.1           55     117.508197                      125.819672
# 4        7.2            6     117.508197                      125.819672
# ...      ...          ...            ...                             ...
# 5720     4.5           18      87.166667                      105.416667
# 5721     4.5           18      87.166667                      105.416667
# 5722     4.8           13      87.166667                      105.416667
# 5723     4.8           18      87.166667                      105.416667
# 5724     4.1           23      87.166667                      105.416667
#
# [5725 rows x 15 columns]

# %%
number_movies = df_final_with_mean_durations.groupby(["channel","month"])["channel"].count().to_frame()

# %%
number_movies
# Out:
#                                channel
# channel             month
# Cielo               agosto          14
#                     aprile          17
#                     febbraio        18
#                     gennaio         16
#                     giugno          20
# ...                                ...
# Sky Cinema Suspense maggio          62
#                     marzo           60
#                     novembre        43
#                     ottobre         47
#                     settembre       55
#
# [110 rows x 1 columns]

# %%
number_movies.rename(columns = {'channel': 'number_movies'}, inplace = True)

# %%
df_final_with_additional_info = pd.merge(df_final_with_mean_durations, number_movies, on=["month","channel"])

# %%
df_final_with_additional_info
# Out:
#             day  day_number    month     daytime   hour  \
# 0       Martedì          25  gennaio       notte  01:10
# 1        Lunedì          24  gennaio       notte  01:10
# 2       Giovedì          20  gennaio  pomeriggio  13:35
# 3        Sabato          29  gennaio       notte  04:10
# 4     Mercoledì           5  gennaio        sera  23:05
# ...         ...         ...      ...         ...    ...
# 5720    Venerdì          20   maggio        sera  21:20
# 5721    Martedì          24   maggio        sera  23:00
# 5722     Sabato          21   maggio        sera  21:20
# 5723  Mercoledì          25   maggio        sera  23:05
# 5724     Sabato          28   maggio        sera  21:20
#
#                                      title  duration  \
# 0                              match point       124
# 1                           the blind side       129
# 2     la leggenda del pianista sull'oceano       169
# 3                               il profeta       100
# 4                          michael clayton       119
# ...                                    ...       ...
# 5720                    spogliando valeria        92
# 5721                    spogliando valeria        92
# 5722                             la nipote        92
# 5723                             la nipote        92
# 5724                          l'attenzione        87
#
#       duration_with_advertising         channel  year                  genres  \
# 0                           125  Sky Cinema Due  2005  Drama,Romance,Thriller
# 1                           130  Sky Cinema Due  2009   Biography,Drama,Sport
# 2                           170  Sky Cinema Due  1998     Drama,Music,Romance
# 3                           155  Sky Cinema Due  1968                  Comedy
# 4                           125  Sky Cinema Due  2007     Crime,Drama,Mystery
# ...                         ...             ...   ...                     ...
# 5720                        110           Cielo  1989        Romance,Thriller
# 5721                        110           Cielo  1989        Romance,Thriller
# 5722                        105           Cielo  1974                  Comedy
# 5723                        110           Cielo  1974                  Comedy
# 5724                        110           Cielo  1985           Drama,Romance
#
#       rating  advertising  duration_mean  duration_with_advertising_mean  \
# 0        7.6            1     117.508197                      125.819672
# 1        7.6            1     117.508197                      125.819672
# 2        8.1            1     117.508197                      125.819672
# 3        6.1           55     117.508197                      125.819672
# 4        7.2            6     117.508197                      125.819672
# ...      ...          ...            ...                             ...
# 5720     4.5           18      87.166667                      105.416667
# 5721     4.5           18      87.166667                      105.416667
# 5722     4.8           13      87.166667                      105.416667
# 5723     4.8           18      87.166667                      105.416667
# 5724     4.1           23      87.166667                      105.416667
#
#       number_movies
# 0                61
# 1                61
# 2                61
# 3                61
# 4                61
# ...             ...
# 5720             12
# 5721             12
# 5722             12
# 5723             12
# 5724             12
#
# [5725 rows x 16 columns]

# %%
# df_final_with_additional_info.to_csv("./dataset/df_final_with_additional_info.csv", index=False)

# %%
df_final_with_additional_info = pd.read_csv("./dataset/df_final_with_additional_info.csv")

# %%
df_final_with_additional_info
# Out:
#             day  day_number    month     daytime   hour  \
# 0       Martedì          25  gennaio       notte  01:10
# 1        Lunedì          24  gennaio       notte  01:10
# 2       Giovedì          20  gennaio  pomeriggio  13:35
# 3        Sabato          29  gennaio       notte  04:10
# 4     Mercoledì           5  gennaio        sera  23:05
# ...         ...         ...      ...         ...    ...
# 5720    Venerdì          20   maggio        sera  21:20
# 5721    Martedì          24   maggio        sera  23:00
# 5722     Sabato          21   maggio        sera  21:20
# 5723  Mercoledì          25   maggio        sera  23:05
# 5724     Sabato          28   maggio        sera  21:20
#
#                                      title  duration  \
# 0                              match point       124
# 1                           the blind side       129
# 2     la leggenda del pianista sull'oceano       169
# 3                               il profeta       100
# 4                          michael clayton       119
# ...                                    ...       ...
# 5720                    spogliando valeria        92
# 5721                    spogliando valeria        92
# 5722                             la nipote        92
# 5723                             la nipote        92
# 5724                          l'attenzione        87
#
#       duration_with_advertising         channel  year                  genres  \
# 0                           125  Sky Cinema Due  2005  Drama,Romance,Thriller
# 1                           130  Sky Cinema Due  2009   Biography,Drama,Sport
# 2                           170  Sky Cinema Due  1998     Drama,Music,Romance
# 3                           155  Sky Cinema Due  1968                  Comedy
# 4                           125  Sky Cinema Due  2007     Crime,Drama,Mystery
# ...                         ...             ...   ...                     ...
# 5720                        110           Cielo  1989        Romance,Thriller
# 5721                        110           Cielo  1989        Romance,Thriller
# 5722                        105           Cielo  1974                  Comedy
# 5723                        110           Cielo  1974                  Comedy
# 5724                        110           Cielo  1985           Drama,Romance
#
#       rating  advertising  duration_mean  duration_with_advertising_mean  \
# 0        7.6            1     117.508197                      125.819672
# 1        7.6            1     117.508197                      125.819672
# 2        8.1            1     117.508197                      125.819672
# 3        6.1           55     117.508197                      125.819672
# 4        7.2            6     117.508197                      125.819672
# ...      ...          ...            ...                             ...
# 5720     4.5           18      87.166667                      105.416667
# 5721     4.5           18      87.166667                      105.416667
# 5722     4.8           13      87.166667                      105.416667
# 5723     4.8           18      87.166667                      105.416667
# 5724     4.1           23      87.166667                      105.416667
#
#       number_movies
# 0                61
# 1                61
# 2                61
# 3                61
# 4                61
# ...             ...
# 5720             12
# 5721             12
# 5722             12
# 5723             12
# 5724             12
#
# [5725 rows x 16 columns]

# %% [markdown]
# ## Manage Genres

# %% [markdown]
# To remove: War, Sport, Musical, Music, Biography, Animation, Adult, Film-Noir, History, Family, Mystery
#
# If we remove Musical -> we will remove 7 movies
#
# Only Documentary: 28 movies

# %%
df_final_with_additional_info[df_final_with_additional_info['genres'].str.contains('Drama')]
# Out:
#             day  day_number      month     daytime   hour  \
# 0       Martedì          25    gennaio       notte  01:10
# 1        Lunedì          24    gennaio       notte  01:10
# 2       Giovedì          20    gennaio  pomeriggio  13:35
# 4     Mercoledì           5    gennaio        sera  23:05
# 5       Venerdì           7    gennaio       notte  01:45
# ...         ...         ...        ...         ...    ...
# 5707    Martedì          13  settembre        sera  23:45
# 5708    Venerdì          16  settembre        sera  23:46
# 5718  Mercoledì           4     maggio        sera  23:05
# 5719     Lunedì           9     maggio        sera  21:15
# 5724     Sabato          28     maggio        sera  21:20
#
#                                      title  duration  \
# 0                              match point       124
# 1                           the blind side       129
# 2     la leggenda del pianista sull'oceano       169
# 4                          michael clayton       119
# 5                                     blow       124
# ...                                    ...       ...
# 5707                        eyes wide shut       159
# 5708                         blood diamond       143
# 5718                        senza scrupoli        83
# 5719                              maryland        92
# 5724                          l'attenzione        87
#
#       duration_with_advertising         channel  year  \
# 0                           125  Sky Cinema Due  2005
# 1                           130  Sky Cinema Due  2009
# 2                           170  Sky Cinema Due  1998
# 4                           125  Sky Cinema Due  2007
# 5                           125  Sky Cinema Due  2001
# ...                         ...             ...   ...
# 5707                        165        Italia 1  1999
# 5708                        154        Italia 1  2006
# 5718                        100           Cielo  1986
# 5719                        115           Cielo  1940
# 5724                        110           Cielo  1985
#
#                         genres  rating  advertising  duration_mean  \
# 0       Drama,Romance,Thriller     7.6            1     117.508197
# 1        Biography,Drama,Sport     7.6            1     117.508197
# 2          Drama,Music,Romance     8.1            1     117.508197
# 4          Crime,Drama,Mystery     7.2            6     117.508197
# 5        Biography,Crime,Drama     7.6            1     117.508197
# ...                        ...     ...          ...            ...
# 5707    Drama,Mystery,Thriller     7.4            6     125.571429
# 5708  Adventure,Drama,Thriller     8.0           11     125.571429
# 5718              Comedy,Drama     5.1           17      87.166667
# 5719                     Drama     5.9           23      87.166667
# 5724             Drama,Romance     4.1           23      87.166667
#
#       duration_with_advertising_mean  number_movies
# 0                         125.819672             61
# 1                         125.819672             61
# 2                         125.819672             61
# 4                         125.819672             61
# 5                         125.819672             61
# ...                              ...            ...
# 5707                      138.285714              7
# 5708                      138.285714              7
# 5718                      105.416667             12
# 5719                      105.416667             12
# 5724                      105.416667             12
#
# [2484 rows x 16 columns]

# %%
df_final_with_additional_info[df_final_with_additional_info['genres'].eq('Crime')]
# Out:
#            day  day_number      month     daytime   hour  \
# 197    Martedì          30     agosto        sera  19:25
# 198    Venerdì          26     agosto     mattina  06:05
# 199    Venerdì          26     agosto        sera  21:15
# 200     Sabato          27     agosto  pomeriggio  13:15
# 495    Venerdì          23  settembre        sera  19:25
# 536     Sabato          29    ottobre  pomeriggio  15:20
# 537   Domenica           2    ottobre        sera  21:15
# 538     Lunedì          17    ottobre        sera  23:15
# 1128    Lunedì          14   novembre  pomeriggio  13:20
# 1768  Domenica          17     luglio     mattina  08:18
# 1769    Sabato          16     luglio        sera  21:07
# 3365  Domenica          27      marzo  pomeriggio  15:25
# 3366    Sabato          26      marzo        sera  21:13
# 4768   Martedì          16     agosto     mattina  08:10
# 4939  Domenica          24     luglio        sera  21:20
# 4940  Domenica          31     luglio  pomeriggio  14:00
#
#                         title  duration  duration_with_advertising  \
# 197                la padrina        95                        110
# 198                la padrina        95                        110
# 199                la padrina        95                        110
# 200                la padrina        95                        110
# 495                la padrina        95                        110
# 536                la padrina        95                        110
# 537                la padrina        95                        110
# 538                la padrina        95                        115
# 1128               la padrina        95                        110
# 1768     la banda del trucido        95                        124
# 1769     la banda del trucido        95                        119
# 3365                duplicity        90                        164
# 3366                duplicity        90                        145
# 4768  i guappi non si toccano        93                        108
# 4939                extortion        61                        120
# 4940                extortion        61                        130
#
#              channel  year genres  rating  advertising  duration_mean  \
# 197   Sky Cinema Due  1973  Crime     6.0           15     121.037736
# 198   Sky Cinema Due  1973  Crime     6.0           15     121.037736
# 199   Sky Cinema Due  1973  Crime     6.0           15     121.037736
# 200   Sky Cinema Due  1973  Crime     6.0           15     121.037736
# 495   Sky Cinema Due  1973  Crime     6.0           15     116.190476
# 536   Sky Cinema Due  1973  Crime     6.0           15     113.481481
# 537   Sky Cinema Due  1973  Crime     6.0           15     113.481481
# 538   Sky Cinema Due  1973  Crime     6.0           20     113.481481
# 1128  Sky Cinema Due  1973  Crime     6.0           15     116.365385
# 1768          Cine34  1977  Crime     6.1           29      97.286458
# 1769          Cine34  1977  Crime     6.1           24      97.286458
# 3365            Iris  2004  Crime     5.2           74     117.100000
# 3366            Iris  2004  Crime     5.2           55     117.100000
# 4768          Cine34  1979  Crime     4.6           15      98.634286
# 4939           Cielo  1938  Crime     5.4           59      91.947368
# 4940           Cielo  1938  Crime     5.4           69      91.947368
#
#       duration_with_advertising_mean  number_movies
# 197                       128.207547             53
# 198                       128.207547             53
# 199                       128.207547             53
# 200                       128.207547             53
# 495                       126.666667             42
# 536                       120.277778             54
# 537                       120.277778             54
# 538                       120.277778             54
# 1128                      126.250000             52
# 1768                      119.734375            192
# 1769                      119.734375            192
# 3365                      142.716667             60
# 3366                      142.716667             60
# 4768                      118.154286            175
# 4939                      112.368421             19
# 4940                      112.368421             19

# %%
df_final_with_additional_info.loc[df_final_with_additional_info['genres'].eq('Mystery')]['genres'] = "Crime"
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def remove_genre(genres: str):
    genres_to_be_removed = {"War", "Sport", "Musical", "Music", "Biography", "Animation", "Adult", "Film-Noir", "History", "Family", "Mystery"}
    genres_set = set(genres.split(","))

    to_be_removed_in_intersection = genres_to_be_removed.intersection(genres_set)

    new_geners_set = genres_set.difference(to_be_removed_in_intersection)

    return ",".join(new_geners_set)

# %%
df_final_with_additional_info['genres'] = df_final_with_additional_info['genres'].apply(remove_genre)

# %%
df_final_with_additional_info = df_final_with_additional_info[df_final_with_additional_info['genres'] != ""]

# %%
# df_final_with_additional_info.to_csv("./dataset/df_final_with_additional_info.csv", index=False)

# %%
df_final_with_additional_info.groupby(['genres'])['genres'].count().index
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Animation',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Romance',
#        ...
#        'Mystery', 'Mystery,Romance,Thriller', 'Mystery,Thriller', 'Romance',
#        'Romance,Thriller', 'Romance,Western', 'Sci-Fi', 'Thriller',
#        'War,Western', 'Western'],
#       dtype='object', name='genres', length=194)

# %%
# Number of movies for channel
df_final.groupby(['channel'])['channel'].count()
# Out:
# channel
# Cielo                 179
# Cine34               1677
# Iris                  553
# Italia 1               94
# Rete 4                263
# Sky Cinema Action     769
# Sky Cinema Comedy     508
# Sky Cinema Drama      556
# Sky Cinema Due        544
# Name: channel, dtype: int64

# %% [markdown]
# # Audit Sharing

# %%
df_with_additional_info = pd.read_csv("./dataset/df_with_additional_info.csv")

# %%
def preprocess_audit_data(data_pah: str):
    months_map = {0: "gennaio", 1: "febbraio", 2: "marzo", 3: "aprile", 4: "maggio", 5: "giugno", 6: "luglio", 7: "agosto", 8: "settembre", 9: "ottobre", 10: "novembre"}
    considered_channels = ["Cielo", "Italia 1", "Iris", "Rete 4", "Cine34", "Sky Cinema Drama", "Sky Cinema Due", "Sky Cinema Suspense", "Sky Cinema Comedy", "Sky Cinema Action"]
    
    
    df_sharings = []
    df_sharings_all_day = []

    for i in range(len(months_map)):
        df_sharings.append(pd.read_excel('./dataset/Audit/sharing.xlsx', index_col=0, sheet_name=i))
    
    for idx, df in enumerate(df_sharings):
        # Rename columns and indices
        df_sharings[idx] = df[2:].rename(columns={'Column2':'type', 
                                    'Column3': 'all_day', 
                                    'Column4': 'mattina_1',
                                    'Column5': 'mattina_2',
                                    'Column6': 'pomeriggio_1',
                                    'Column7': 'pomeriggio_2',
                                    'Column8': 'sera_1',
                                    'Column9': 'sera_2',
                                    'Column10': 'notte',
                                    })

        df_sharings[idx].index.name = "channel"
        df_sharings[idx].rename(index={'Cine 34':'Cine34'}, inplace=True)
        df_sharings[idx] = df_sharings[idx][df_sharings[idx]['type'] == "SH"]


        # Filter on selected channels
        df_sharings[idx] = df_sharings[idx].loc[df_sharings[idx].index.isin(considered_channels)]

        # Average on daytime
        df_sharings[idx]['mattina'] = df_sharings[idx][['mattina_1', 'mattina_2']].mean(axis=1)
        df_sharings[idx]['pomeriggio'] = df_sharings[idx][['pomeriggio_1', 'pomeriggio_2']].mean(axis=1)
        df_sharings[idx]['sera'] = df_sharings[idx][['sera_1', 'sera_2']].mean(axis=1)

        df_sharings_all_day.append(pd.concat({months_map[idx]: df_sharings[idx]['all_day']}, names=['month']))
        df_sharings[idx] = df_sharings[idx][['mattina', 'pomeriggio', 'sera', 'notte']]

 
        # Rearrange columns in a multi-index fashion
        df_sharings[idx] = df_sharings[idx].stack(0).to_frame()
        df_sharings[idx].rename_axis(["channel", "daytime"], inplace=True)
        df_sharings[idx].rename(columns={0: "sharing"}, inplace=True)
        df_sharings[idx] = pd.concat({months_map[idx]: df_sharings[idx]}, names=['month'])

    return pd.concat(df_sharings_all_day).to_frame(), pd.concat(df_sharings)

# %%
sharings_path = './dataset/Audit/sharing.xlsx'
df_sharings_all_day, df_sharings = preprocess_audit_data(sharings_path)

# %%
df_sharings_all_day
# Out:
#                               all_day
# month    channel
# gennaio  Italia 1                4.30
#          Rete 4                  3.71
#          Iris                    1.34
#          Cine34                  0.89
#          Sky Cinema Action       0.10
# ...                               ...
# novembre Sky Cinema Comedy       0.07
#          Sky Cinema Drama        0.04
#          Sky Cinema Due          0.06
#          Sky Cinema Suspense     0.06
#          Cielo                   0.95
#
# [110 rows x 1 columns]

# %%
df_sharings
# Out:
#                                          sharing
# month    channel             daytime
# gennaio  Italia 1            mattina       2.260
#                              pomeriggio    4.180
#                              sera          4.400
#                              notte         5.840
#          Rete 4              mattina       1.655
# ...                                          ...
# novembre Sky Cinema Suspense notte         0.080
#          Cielo               mattina       0.525
#                              pomeriggio    1.045
#                              sera          0.750
#                              notte         1.520
#
# [440 rows x 1 columns]

# %%
df_final_with_additional_info = pd.merge(df_with_additional_info, df_sharings, on=["channel", "daytime", "month"])

# %%
df_final_with_additional_info
# Out:
#             day  day_number    month     daytime   hour               title  \
# 0       Martedì          25  gennaio       notte  01:10         match point
# 1        Lunedì          24  gennaio       notte  01:10      the blind side
# 2        Sabato          29  gennaio       notte  04:10          il profeta
# 3       Venerdì           7  gennaio       notte  01:45                blow
# 4        Sabato          22  gennaio       notte  01:25                blow
# ...         ...         ...      ...         ...    ...                 ...
# 5713    Martedì          24   maggio        sera  23:00  spogliando valeria
# 5714     Sabato          21   maggio        sera  21:20           la nipote
# 5715  Mercoledì          25   maggio        sera  23:05           la nipote
# 5716     Sabato          28   maggio        sera  21:20        l'attenzione
# 5717   Domenica          22   maggio  pomeriggio  14:05  born to raise hell
#
#       duration  duration_with_advertising         channel  year  \
# 0          124                        125  Sky Cinema Due  2005
# 1          129                        130  Sky Cinema Due  2009
# 2          100                        155  Sky Cinema Due  1968
# 3          124                        125  Sky Cinema Due  2001
# 4          124                        125  Sky Cinema Due  2001
# ...        ...                        ...             ...   ...
# 5713        92                        110           Cielo  1989
# 5714        92                        105           Cielo  1974
# 5715        92                        110           Cielo  1974
# 5716        87                        110           Cielo  1985
# 5717        90                        115           Cielo  1975
#
#                       genres  rating  advertising  duration_mean  \
# 0     Romance,Thriller,Drama     7.6            1     117.508197
# 1                      Drama     7.6            1     117.508197
# 2                     Comedy     6.1           55     117.508197
# 3                Crime,Drama     7.6            1     117.508197
# 4                Crime,Drama     7.6            1     117.508197
# ...                      ...     ...          ...            ...
# 5713        Romance,Thriller     4.5           18      87.166667
# 5714                  Comedy     4.8           13      87.166667
# 5715                  Comedy     4.8           18      87.166667
# 5716           Romance,Drama     4.1           23      87.166667
# 5717                  Horror     7.2           25      87.166667
#
#       duration_with_advertising_mean  number_movies  sharing
# 0                         125.819672             61    0.140
# 1                         125.819672             61    0.140
# 2                         125.819672             61    0.140
# 3                         125.819672             61    0.140
# 4                         125.819672             61    0.140
# ...                              ...            ...      ...
# 5713                      105.416667             12    0.905
# 5714                      105.416667             12    0.905
# 5715                      105.416667             12    0.905
# 5716                      105.416667             12    0.905
# 5717                      105.416667             12    1.015
#
# [5718 rows x 17 columns]

# %%
# df_final_with_additional_info.to_csv("./dataset/df_final_with_additional_info.csv", index=False)

# %%
df_sharings_all_day
# Out:
#                               all_day
# month    channel
# gennaio  Italia 1                4.30
#          Rete 4                  3.71
#          Iris                    1.34
#          Cine34                  0.89
#          Sky Cinema Action       0.10
# ...                               ...
# novembre Sky Cinema Comedy       0.07
#          Sky Cinema Drama        0.04
#          Sky Cinema Due          0.06
#          Sky Cinema Suspense     0.06
#          Cielo                   0.95
#
# [110 rows x 1 columns]

# %%
df_sharings_all_day_channel_first = df_sharings_all_day.sort_values(by="channel").swaplevel()

# %%
df_sharings_all_day_channel_first
# Out:
#                                all_day
# channel             month
# Cielo               novembre      0.95
#                     maggio        1.04
#                     marzo         0.87
#                     giugno        1.07
#                     luglio        1.07
# ...                                ...
# Sky Cinema Suspense maggio        0.05
#                     settembre     0.06
#                     agosto        0.07
#                     giugno        0.07
#                     febbraio      0.05
#
# [110 rows x 1 columns]

# %%
channel_month_count = df_with_additional_info.groupby(['channel', 'month'])['channel'].count().to_frame()
channel_month_count.rename(columns={"channel": "number_movies"}, inplace=True)

# %%
channel_month_count
# Out:
#                                number_movies
# channel             month
# Cielo               agosto                14
#                     aprile                17
#                     febbraio              18
#                     gennaio               16
#                     giugno                20
# ...                                      ...
# Sky Cinema Suspense maggio                62
#                     marzo                 60
#                     novembre              43
#                     ottobre               47
#                     settembre             55
#
# [110 rows x 1 columns]

# %%
channel_month_count['sharing'] = df_sharings_all_day_channel_first['all_day']

# %%
channel_month_count
# Out:
#                                number_movies  sharing
# channel             month
# Cielo               agosto                14     1.12
#                     aprile                17     0.94
#                     febbraio              18     0.85
#                     gennaio               16     0.84
#                     giugno                20     1.07
# ...                                      ...      ...
# Sky Cinema Suspense maggio                62     0.05
#                     marzo                 60     0.05
#                     novembre              43     0.06
#                     ottobre               47     0.05
#                     settembre             55     0.06
#
# [110 rows x 2 columns]

# %%
# channel_month_count.to_csv("./dataset/channel_month_count_sharing.csv")

# %%
channel_month_count = pd.read_csv("./dataset/channel_month_count_sharing.csv")

# %%
channel_month_count['number_movies'].describe()
# Out:
# count    110.000000
# mean      51.981818
# std       39.360713
# min        4.000000
# 25%       21.500000
# 50%       47.000000
# 75%       61.000000
# max      192.000000
# Name: number_movies, dtype: float64

# %%
channel_month_day_count = df_final.groupby(['channel', 'month', 'day_number', 'rating'])['channel'].count()

# %%
channel_month_day_count.to_frame()['channel']
# Out:
# channel         month      day_number  rating
# Cielo           agosto     2           5.4       1
#                            3           5.7       1
#                            5           5.3       1
#                                        6.4       1
#                            9           5.3       1
#                                                 ..
# Sky Cinema Due  settembre  26          5.6       2
#                            27          5.2       1
#                                        5.6       1
#                            28          7.3       1
#                            30          8.3       1
# Name: channel, Length: 4802, dtype: int64

# %%
channel_month_count = df_final.groupby(['channel', 'month'])['channel'].count()

# %%
channel_month_count.to_frame()
# Out:
#                           channel
# channel        month
# Cielo          agosto          14
#                aprile          17
#                febbraio        18
#                gennaio         16
#                giugno          20
# ...                           ...
# Sky Cinema Due maggio          46
#                marzo           40
#                novembre        52
#                ottobre         54
#                settembre       42
#
# [99 rows x 1 columns]

# %%
df_final[df_final['channel'] == "Italia 1"]['genres'].unique()
# Out:
# array(['Action,Adventure,Thriller', 'Action,Drama,Sci-Fi',
#        'Action,Fantasy,Thriller', 'Action,Sci-Fi,Thriller',
#        'Horror,Mystery,Thriller', 'Action,Adventure,Sci-Fi',
#        'Action,Crime,Thriller', 'Drama,Sci-Fi', 'Drama',
#        'Action,Comedy,Thriller', 'Mystery,Thriller',
#        'Action,Adventure,Fantasy', 'Comedy', 'Action,Adventure',
#        'Drama,Romance', 'Drama,Mystery,Thriller', 'Comedy,Music',
#        'Action,Thriller', 'Action,Crime', 'Adventure,Animation,Comedy',
#        'Action,Fantasy,Horror', 'Action,Comedy,Crime', 'Horror',
#        'Action,Adventure,Comedy', 'Romance', '\\N',
#        'Action,Adventure,Crime', 'Sci-Fi', 'Comedy,Family',
#        'Comedy,Drama,Romance', 'Comedy,Fantasy,Horror',
#        'Adventure,Sci-Fi,Thriller', 'Drama,Horror,Mystery',
#        'Drama,Sci-Fi,Thriller', 'Action,Horror,Sci-Fi', 'Comedy,Drama',
#        'Action,Adventure,War', 'Adventure,Comedy'], dtype=object)

# %%
sky_comedy = df_final[df_final['channel'] == "Sky Cinema Comedy"]

# %%
sky_comedy.groupby(['genres'])['genres'].count()
# Out:
# genres
# Action,Adventure,Comedy       6
# Action,Comedy,Crime          20
# Action,Comedy,Fantasy         7
# Action,Comedy,Mystery         4
# Action,Comedy,Thriller        2
# Adventure,Comedy              2
# Adventure,Comedy,Fantasy      4
# Adventure,Comedy,Sci-Fi       2
# Comedy                      132
# Comedy,Crime                  5
# Comedy,Drama                 14
# Comedy,Drama,Music            2
# Comedy,Family,Sport           2
# Comedy,Fantasy                3
# Comedy,History,War            1
# Comedy,Horror                 5
# Comedy,Romance                9
# Documentary                   9
# Drama,History                 1
# \N                            2
# Name: genres, dtype: int64

# %%
df_final[df_final['channel'] == "Sky Cinema Comedy"]['genres'].unique()
# Out:
# array(['Comedy', 'Action,Comedy,Crime', 'Comedy,Crime', 'Comedy,Drama',
#        'Adventure,Comedy,Fantasy', 'Documentary', 'Action,Comedy,Fantasy',
#        'Comedy,History,War', 'Comedy,Family,Sport',
#        'Action,Adventure,Comedy', 'Action,Comedy,Mystery',
#        'Comedy,Fantasy', 'Drama,History', 'Comedy,Romance',
#        'Adventure,Comedy', 'Action,Comedy,Thriller', 'Comedy,Horror',
#        '\\N', 'Comedy,Drama,Music', 'Adventure,Comedy,Sci-Fi'],
#       dtype=object)

# %%
df_final[df_final['channel'] == "Sky Cinema Action"]['genres'].unique()
# Out:
# array(['Action,Adventure,Comedy', 'Action,Crime,Drama', 'Drama,Romance',
#        'Action,Sci-Fi', 'Drama', 'Western', 'Action,Adventure',
#        'Crime,Drama,Thriller', 'Crime,Mystery,Thriller',
#        'Action,Thriller', 'Action,Sport,Thriller',
#        'Action,Adventure,Sci-Fi', 'Action,Adventure,Thriller',
#        'Action,Drama,Sci-Fi', 'Comedy,Sci-Fi', 'Action,Fantasy,Thriller',
#        'Action,Sci-Fi,Thriller', 'Drama,War', 'Action,Adventure,Romance',
#        'Biography,Crime,Drama', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Fantasy', '\\N', 'Action,Adventure,Drama',
#        'Action,Crime,Thriller', 'Documentary', 'Action,Drama,Thriller',
#        'Drama,History,Western', 'Drama,Mystery,Thriller',
#        'Action,Drama,Fantasy', 'Action,Crime,Mystery',
#        'Action,Drama,Mystery', 'Action,Comedy,Crime', 'Horror,Sci-Fi',
#        'Action,Crime,Fantasy', 'Action,Adventure,Fantasy',
#        'Crime,Drama,Mystery', 'Comedy', 'Comedy,Western',
#        'Drama,History,War', 'Action', 'Drama,History', 'Fantasy',
#        'Action,Drama', 'Crime,Drama', 'Adventure,Comedy,Crime',
#        'Action,Mystery,Thriller', 'Action,Crime,Sci-Fi'], dtype=object)

# %%
df_final[df_final['channel'] == "Sky Cinema Uno"]['genres'].unique()
# Out:
# array(['Action,Crime,Drama', 'Fantasy,Horror,Mystery', 'Drama,Romance',
#        'Comedy', 'Action,Adventure', 'Action,Adventure,Sci-Fi',
#        'Crime,Drama,Thriller', 'Action,Comedy,Crime',
#        'Crime,Mystery,Thriller', 'Action,Thriller',
#        'Adventure,Drama,Sci-Fi', 'Drama', 'Biography,Crime,Drama',
#        'Drama,Fantasy,Mystery', 'Action,Adventure,Thriller',
#        'Documentary,War', 'Comedy,Drama,Romance', 'Comedy,Sci-Fi',
#        'Action,Drama,Sci-Fi', 'Documentary', 'Comedy,Romance,Sport',
#        'Action,Sci-Fi,Thriller', 'Crime,Drama,Music',
#        'Action,Adventure,Drama', 'Action,Crime,Thriller', 'Thriller',
#        'Comedy,Musical', 'Drama,History', '\\N', 'Drama,Sci-Fi',
#        'Drama,Mystery,Thriller', 'Action,Drama,Fantasy',
#        'Action,Drama,Mystery', 'Action,Fantasy,Horror',
#        'Action,Drama,Horror', 'Action,Adventure,Comedy',
#        'Action,Mystery,Sci-Fi', 'Action,Crime,Fantasy',
#        'Action,Adventure,Fantasy', 'Comedy,Romance',
#        'Crime,Drama,Mystery', 'Adventure,Comedy,Drama', 'Crime',
#        'Drama,Fantasy,Romance', 'Action,Adventure,Animation', 'Sport',
#        'Adventure,Drama,Thriller', 'Action,Drama,History',
#        'Drama,History,War', 'Drama,History,Romance',
#        'Action,Horror,Sci-Fi', 'Action,Mystery,Thriller'], dtype=object)

# %%
# Get all genres
np_genres = df_final['genres'].unique()

# %%
genres_set = set()

for genres in np_genres:
    genres_set = genres_set.union(set(genres.split(",")))

# %%
genres_set
# Out:
# {'Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

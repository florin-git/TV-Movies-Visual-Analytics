# %%
import pandas as pd

# %%
dataset_path = "./dataset/movie_without_december.tsv"

# %%
df = pd.read_csv(dataset_path, sep="\t")

# %%
df
# Out:
#             day  day_number    month     daytime   hour  \
# 0       Martedì          25  gennaio       notte  01:01
# 1       Martedì          25  gennaio       notte  01:10
# 2       Martedì          25  gennaio       notte  01:10
# 3       Martedì          25  gennaio       notte  01:15
# 4       Martedì          25  gennaio       notte  01:22
# ...         ...         ...      ...         ...    ...
# 69621  Domenica          24   aprile  pomeriggio  16:15
# 69622  Domenica          24   aprile  pomeriggio  16:15
# 69623  Domenica          24   aprile  pomeriggio  16:35
# 69624  Domenica          24   aprile  pomeriggio  16:55
# 69625  Domenica          24   aprile  pomeriggio  16:55
#
#                                title duration                  channel
# 0               Piccolo grande aaron     105'                     Iris
# 1                        Match Point     125'           Sky Cinema Due
# 2                     The Blind Side     130'       Sky Cinema Due +24
# 3               From Paris with love      95'        Sky Cinema Action
# 4                   Volesse il cielo      87'                   Cine34
# ...                              ...      ...                      ...
# 69621                 Transformers 4     165'  Harry Potter Collection
# 69622                    Cloud Atlas     175'         Sky Cinema Drama
# 69623                     Il Padrino     175'            Sky Cinema 4K
# 69624                      Tre piani     125'           Sky Cinema Due
# 69625  Delicieux: l'amore e' servito     120'       Sky Cinema Due +24
#
# [69626 rows x 8 columns]

# %%
# Make titles in lower case
df['title'] = df['title'].str.lower()

# %%
tv_movies = df['title'].unique()

# %%
tv_movies.shape
# Out:
# (7749,)

# %%
kaggle_path = "./dataset/Kaggle/ImdbTitleBasics.csv"

# %%
df_imdb = pd.read_csv(kaggle_path, sep=",")
# Out:
# c:\Users\flori\miniconda3\envs\DL\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_imdb
# Out:
#              tconst  titleType                         primaryTitle  \
# 0         tt0000001      short                           Carmencita
# 1         tt0000002      short               Le clown et ses chiens
# 2         tt0000003      short                       Pauvre Pierrot
# 3         tt0000004      short                          Un bon bock
# 4         tt0000005      short                     Blacksmith Scene
# ...             ...        ...                                  ...
# 1048570  tt10140376   tvSeries                      Começar do Zero
# 1048571  tt10140378  tvEpisode                           Corey Hart
# 1048572   tt1014037  tvEpisode                               Escape
# 1048573  tt10140380      short                         Fear of Dogs
# 1048574  tt10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 0                                 Carmencita        0      1894      \N
# 1                     Le clown et ses chiens        0      1892      \N
# 2                             Pauvre Pierrot        0      1892      \N
# 3                                Un bon bock        0      1892      \N
# 4                           Blacksmith Scene        0      1893      \N
# ...                                      ...      ...       ...     ...
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 1048570             90                Reality-TV
# 1048571             \N                 Talk-Show
# 1048572             29               Documentary
# 1048573             \N               Drama,Short
# 1048574             \N                     Music
#
# [1048575 rows x 9 columns]

# %%
df_imdb.rename(columns = {'originalTitle':'title'}, inplace = True)
df_imdb['title'] = df_imdb['title'].str.lower()
df_imdb['primaryTitle'] = df_imdb['primaryTitle'].str.lower()

# %%
only_movies = df_imdb[df_imdb['titleType'] == "movie"]

# %%
only_movies_without_duplicates = only_movies.drop_duplicates(subset=['title'], keep=False)

# %%
only_movies_without_duplicates
# Out:
#              tconst titleType                    primaryTitle  \
# 570       tt0000574     movie     The Story of the Kelly Gang
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# 729       tt0000739     movie       El pastorcito de Torrente
# 804       tt0000814     movie          La bocana de Mar Chica
# 828       tt0000838     movie              A Cultura do Cacau
# ...             ...       ...                             ...
# 1048453  tt10140138     movie                         Krocken
# 1048479  tt10140192     movie           Le calvaire de Mignon
# 1048497  tt10140224     movie                     Inner Child
# 1048537  tt10140310     movie            A Rock N' Roll Heart
# 1048566  tt10140360     movie          Another Night in China
#
#                                   title  isAdult startYear endYear  \
# 570         the story of the kelly gang        0      1906      \N
# 672      the fairylogue and radio-plays        0      1908      \N
# 729           el pastorcito de torrente        0      1908      \N
# 804              la bocana de mar chica        0      1909      \N
# 828                  a cultura do cacau        0      1909      \N
# ...                                 ...      ...       ...     ...
# 1048453                         krocken        0      2018      \N
# 1048479           le calvaire de mignon        0      1917      \N
# 1048497                     inner child        0        \N      \N
# 1048537            a rock n' roll heart        0      2019      \N
# 1048566          another night in china        1      2009      \N
#
#         runtimeMinutes                      genres
# 570                 70  Action,Adventure,Biography
# 672                120           Adventure,Fantasy
# 729                 \N                       Drama
# 804                 \N                          \N
# 828                 \N                          \N
# ...                ...                         ...
# 1048453             82                Comedy,Drama
# 1048479             55                     Romance
# 1048497             \N            Fantasy,Thriller
# 1048537             77              Comedy,Romance
# 1048566             \N                       Adult
#
# [200720 rows x 9 columns]

# %%
df_merge = pd.merge(df, only_movies_without_duplicates, how="inner", on="title")

# %%
titles_merge = df_merge['title'].unique()

# %%
titles_merge.shape
# Out:
# (1751,)
